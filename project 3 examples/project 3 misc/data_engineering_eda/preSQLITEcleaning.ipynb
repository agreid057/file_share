# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# %%
# Study data files
super_charger_path = "../resources/Supercharge_Locations.csv"

# %%
# Method 2: Improved Reading using CSV module

#with open(super_charger_path) as csvfile:

    # CSV reader specifies delimiter and variable that holds contents
   # super_charger = csv.reader(csvfile, delimiter=',')
#
    #print(super_charger)

    # Read the header row first (skip this step if there is no header)
   # csv_header = next(super_charger)
   # print(f"CSV Header: {csv_header}")

    # Read each row of data after the header
    #for row in super_charger:
      #  print(row)

# %%
# Read the mouse data and the study results
super_charger = pd.read_csv(super_charger_path, encoding='latin1')

# %%
#using .info to make sure everthing looks okay before merging the data frames
super_charger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5876 entries, 0 to 5875
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Supercharger    5876 non-null   object
#  1   Street Address  5876 non-null   object
#  2   City            5876 non-null   object
#  3   State           5754 non-null   object
#  4   Zip             3947 non-null   object
#  5   Country         5876 non-null   object
#  6   Stalls          5876 non-null   int64
#  7   kW              5870 non-null   float64
#  8   GPS             5876 non-null   object
#  9   Elev(m)         5876 non-null   int64
#  10  Open Date       5126 non-null   object
#  11  Unnamed: 11     0 non-null      float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 551.0+ KB

# %%
super_charger.head(10)
# Out:
#                            Supercharger  \
# 0                          Buellton, CA
# 1                           Corning, CA
# 2                           Barstow, CA
# 3                            Tifton, GA
# 4                         Roseville, CA
# 5                            Oxnard, CA
# 6  Daytona Beach - Gateway North Dr, FL
# 7                    Port St. Lucie, FL
# 8                  Dallas - Park Ln, TX
# 9                  Dangjin, South Korea
#
#                                       Street Address            City  \
# 0                                    555 McMurray Rd        Buellton
# 1                                         950 Hwy 99         Corning
# 2                                    2812 Lenwood Rd         Barstow
# 3                                       1310 U.S. 82          Tifton
# 4                                 1151 Galleria Blvd       Roseville
# 5                                  2751 Park View Ct          Oxnard
# ...

# %%
print(super_charger.columns)
# Out:
# Index(['Supercharger', 'Street Address', 'City', 'State', 'Zip', 'Country',
#        'Stalls', 'kW', 'GPS', 'Elev(m)', 'Open Date', 'Unnamed: 11'],
#       dtype='object')

# %%
#dropping the zip column and the un named column
clean_super_charger = super_charger.drop(['Unnamed: 11','Zip'], axis=1, inplace=False)

# %%
clean_super_charger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5876 entries, 0 to 5875
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Supercharger    5876 non-null   object
#  1   Street Address  5876 non-null   object
#  2   City            5876 non-null   object
#  3   State           5754 non-null   object
#  4   Country         5876 non-null   object
#  5   Stalls          5876 non-null   int64
#  6   kW              5870 non-null   float64
#  7   GPS             5876 non-null   object
#  8   Elev(m)         5876 non-null   int64
#  9   Open Date       5126 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 459.2+ KB

# %%
#dropping remaining null values 
clean_super_charger = clean_super_charger.dropna(axis=0, how="any")
clean_super_charger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5026 entries, 0 to 5125
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Supercharger    5026 non-null   object
#  1   Street Address  5026 non-null   object
#  2   City            5026 non-null   object
#  3   State           5026 non-null   object
#  4   Country         5026 non-null   object
#  5   Stalls          5026 non-null   int64
#  6   kW              5026 non-null   float64
#  7   GPS             5026 non-null   object
#  8   Elev(m)         5026 non-null   int64
#  9   Open Date       5026 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 431.9+ KB

# %%
clean_super_charger.tail(30)
# Out:
#                                      Supercharger  \
# 5096                  Dasing Bauernmarkt, Germany
# 5097                            Türkheim, Germany
# 5098                              Motten, Germany
# 5099                            Erlangen, Germany
# 5100         Neumünster - Freesen Center, Germany
# 5101                        Zella-Mehlis, Germany
# 5102                            Panketal, Germany
# 5103                          Gelnhausen, Germany
# 5104                              Pyhtää, Finland
# 5105                           Strasbourg, France
# 5106                           Eurotunnel, France
# 5107                               Wavre, Belgium
# 5108                             Bordeaux, France
# 5109             Aire des Portes d'Angers, France
# 5110                           Rivesaltes, France
# 5111                               Megève, France
# 5112                              Avallon, France
# 5113                                 Alta, Norway
# ...

# %%
# Export the City_Data into a csv
clean_super_charger.to_csv("../resources/clean_super_charger.csv", index= False)
